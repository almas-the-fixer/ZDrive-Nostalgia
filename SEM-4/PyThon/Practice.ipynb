# %%
dict = {"A":'abcdef',"B":'def'}
print("Old: ",dict)
dict["A"] = 1234
print("Updated: ",dict)
## Dictionary is Mutable !!
# Out:
# Old:  {'A': 'abcdef', 'B': 'def'}
# Updated:  {'A': 1234, 'B': 'def'}

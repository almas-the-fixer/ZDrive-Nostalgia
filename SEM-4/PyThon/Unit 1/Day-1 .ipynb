# %%
print("Hello!!")
# Out:
# Hello!!

# %%
name = input("Enter Your Name: ")
print("Hello "+name+"!")
# Out:
# Enter Your Name: Almas
# Hello Almas!

# %%
x = int(input("Enter First Number: "))
y = int(input("Enter Second Number: "))
sum = x+y
print("Sum is",sum)
# Out:
# Enter First Number: 10
# Enter Second Number: 20
# Sum is 30

# %%
x = int(input("Enter your age: "))
if x>18:
    print("Over 18")
elif x==18:
    print("Exactly 18")
else:
    print("Under 18")
# Out:
# Enter your age: 18
# Exactly 18

# %%
n1 = int(input("Enter 1st Number: "))
n2 = int(input("Enter 2nd Number: "))

print("1st no: ",n1)
print("2nd no: ",n2)

#n1 = n1+n2
#n2 = n1-n2 #Old logic
#n1 = n1-n2

n1,n2 = n2,n1 #Python logic



print("1st no: ",n1)
print("2nd no: ",n2)
# Out:
# Enter 1st Number: 1
# Enter 2nd Number: 2
# 1st no:  1
# 2nd no:  2
# 1st no:  2
# 2nd no:  1

# %%
number = int(input("Enter a number to reverse: "))
str_number = str(number)
rev_str = str_number[::-1]
rev_num = int(rev_str)
print("After Reversing: ",rev_num)
# Out:
# Enter a number to reverse: 123
# After Reversing:  321

# %%
#Checking if number is armstrong or not

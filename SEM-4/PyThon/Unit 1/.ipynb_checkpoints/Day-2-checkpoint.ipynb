# %%
print("Hello Day 2 of Python")
X = input("Enter a Number: ")
print(type(X))

length = len(X)

total = 0
for digit in X:
    ans = int(digit)**length
    total = total + ans
print(total)

if total == int(X):
    print("Number is Armstrong!")
else:
    print("Number is NOT Armstrong!")
# Out:
# Hello Day 2 of Python
# Enter a Number: 4
# <class 'str'>
# 4
# Number is Armstrong!

# %%
x = int(input("Enter a Number: "))
print("Your Entered Number:",x)
for i in range(2,x-1):
    if x%i == 0:
        print("NOT Prime Number!")
        break
else:
        print("Prime Number!")

# %%
r = int(input("Enter a range: "))
print("Your Entered range:",r)

for i in range(1,r):
    for j in range(1,i-1)
        if i%j != 0:
            print("Prime Number: ",i)
# Out:
#   File "C:\Users\IMCAC2~1\AppData\Local\Temp/ipykernel_2112/3159642587.py", line 5
#     for j in range(2,i-1)
#                          ^
# SyntaxError: invalid syntax
